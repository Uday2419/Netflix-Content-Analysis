# %% [markdown]
# # Netflix Movies & TV Shows Data Analysis
#
# ## Objective
# Analyze Netflix's dataset using Python to discover trends, clean data, and create meaningful visualizations.

# %%
import pandas as ps
import nu
